# %% [markdown]
# ## Bitcoin Price Analysis
#
# ### Introduction:
# Bitcoin is a cryptographic protocol distributed network that enables users to,store, and transfer digital currency. Thescheme was first implemented by Satoshi Nakamoto in January 2009. Based on the transparency and security of the Bitcoin protocol, the Bitcoin ecosystem has gained significant traction from consumers, businesses, speculators and investors.
# Source: http://snap.stanford.edu/class/cs224w2015/projects_2015/Using_the_Bitcoin_Transaction_Graph_to_Predict_the_Price_of_Bitcoin.pdf
#
# ### Problem statement
# We have received a problem statement regarding the analysis of bitcoins given the historic price of bitcoins.For this purpose Colaberry has provided us with a very extensive data set consisting of the following variables:
#
# Data set given:
# The dataset consists of the following variables:
#
# • Date : Date of observation
#
# • btc_market_price : Average USD market price across major bitcoin exchanges.
#
# • btc_total_bitcoins : The total number of bitcoins that have already been mined.
#
# • btc_market_cap : The total USD value of bitcoin supply in circulation.
#
# • btc_trade_volume : The total USD value of trading volume on major bitcoin exchanges.
#
# • btc_blocks_size : The total size of all block headers and transactions.
#
# • btc_avg_block_size : The average block size in MB.
#
# • btc_n_orphaned_blocks : The total number of blocks mined but ultimately not attached to the main Bitcoin blockchain.
#
# • btc_n_transactions_per_block : The average number of transactions per block.
#
# • btc_median_confirmation_time : The median time for a transaction to be accepted into a mined block.
#
# • btc_hash_rate : The estimated number of tera hashes per second the Bitcoin network is performing.
#
# • btc_difficulty : A relative measure of how difficult it is to find a new block.
#
# • btc_miners_revenue : Total value of coinbase block rewards and transaction fees paid to miners.
#
# • btc_transaction_fees : The total value of all transaction fees paid to miners.
#
# • btc_cost_per_transaction_percent : miners revenue as percentage of the transaction volume.
#
# • btc_cost_per_transaction : miners revenue divided by the number of transactions.
#
# • btc_n_unique_addresses : The total number of unique addresses used on the Bitcoin blockchain.
#
# • btc_n_transactions : The number of daily confirmed Bitcoin transactions.
#
# • btc_n_transactions_total : Total number of transactions.
#
# • btc_n_transactions_excluding_popular : The total number of Bitcoin transactions, excluding the 100 most popular addresses.
#
# • btc_n_transactions_excluding_chains_longer_than_100 : The total number of Bitcoin transactions per day excluding longtransaction chains.
#
# • btc_output_volume : The total value of all transaction outputs per day.
#
# • btc_estimated_transaction_volume : The total estimated value of transactions on the Bitcoin blockchain.
#
# ### Exercise:
# 1)Ingest the data into a format that is easy for analysis.
#
# 2)Perform Exploratory Data Analysis on the dataset.
#
# 3)Can you predict the future price of the dataset?
#
# ### Step1:
# The first step here is to import the required libraries inorder to enable plotting,applying statistical methods to analyse the data etc.Create a dataset named as'btcoin_df' and read data from the github link provided below: https://raw.githubusercontent.com/colaberry/data/master/Bitcoin/bitcoin_dataset.csv

# %%
#Import the required libraries
import numpy as np 
import pandas as pd 
import datetime as dt
import matplotlib
import matplotlib.pyplot as plt

#read the data into the required dataset from the link:https://raw.githubusercontent.com/colaberry/data/master/Bitcoin/bitcoin_dataset.csv
btcoin_df = pd.read_csv('https://raw.githubusercontent.com/colaberry/data/master/Bitcoin/bitcoin_dataset.csv')
btcoin_df.head()
btcoin_df.shape
# Out:
# (2906, 24)

# %% [markdown]
# Read the data into the required dataset from the link and extract the first few cells using .head()

# %%
btcoin_df = pd.read_csv('https://raw.githubusercontent.com/colaberry/data/master/Bitcoin/bitcoin_dataset.csv')
btcoin_df.head()
btcoin_df.shape
# Out:
# (2906, 24)

# %%
#Import the required libraries
import numpy as np 
import pandas as pd 
import csv

try:
    def verify_answer():
        if btcoin_df.shape==(2906, 24):
            return True
                 
    ref_assert_var = verify_answer()
except Exception as e:
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')
# Out:
# continue

# %% [markdown]
# ### Step 2:
# Now that our dataset has been loaded with the raw data extracted from the link,we then proceed onto Exploratory Data Analysis of the obtained data.
# First we plot a simple chart so as to ensure that the data obtained is correct.
# The execution step has been demonstrated to you just replace the 'your parameter' with the 'btc_market_price' and plot using pyplot.scatter

# %%
# Chart the BTC pricing data-importing libraries
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# Plot a scatter plot of bitcoin market price versus the index.

# %%
import matplotlib
import matplotlib.pyplot as plt
btc_trace=matplotlib.pyplot.scatter(x=btcoin_df.index, y=btcoin_df['btc_market_price'])

# %%
#this is assertion block which verifies the solution.

try:
    def verify_answer():
        return True

    ref_assert_var = verify_answer()
except Exception as e:
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')

# %% [markdown]
# ## Analysis:
# ### Basic Statistical Operations:
# Now we describe the data frame which results in numerical values such as: count,mean,min and max values etc.
# ### Reference:
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.describe.html

# %%
import seaborn as sns

ax = sns.boxplot(data=btcoin_df['btc_market_price'], orient="h")

# %% [markdown]
# The above data is visualised in a box plot.A box plot shows the quartiles of the dataset with points that are determined to be outliers using a method of the inter-quartile range (IQR). In other words, the IQR is the first quartile (25%) subtracted from the third quartile (75%).Here btc_market_price is taken.

# %%
btcoin_df['btc_market_price'].hist(bins=50, figsize=(15,10)).axvline(btcoin_df['btc_market_price'].median(), color='r', linestyle='dashed', linewidth=1)

# %%
#this is assertion block which verifies the solution.

try:
    def verify_answer():
           return True

    ref_assert_var = verify_answer()
except Exception as e:
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')

# %% [markdown]
# ### Histograms:
# Now let us estimate the Frequency distribution of 'btc_market_price'.The histogram shows the value of Bitcoin Market Price against index.We observe that the plot has right skewed distribution.
#
#  ### Reference:
#  https://docs.scipy.org/doc/numpy/reference/generated/numpy.histogram.html
#  https://pythonspot.com/matplotlib-histogram/

# %%
btcoin_df_num = btcoin_df.select_dtypes(include = ['float64', 'int64'])
btcoin_df_num.head()
# Out:
#    btc_market_price  btc_total_bitcoins  btc_market_cap  btc_trade_volume  \
# 0               0.0           2043200.0             0.0               0.0
# 1               0.0           2054650.0             0.0               0.0
# 2               0.0           2063600.0             0.0               0.0
# 3               0.0           2074700.0             0.0               0.0
# 4               0.0           2085400.0             0.0               0.0
#
#    btc_blocks_size  btc_avg_block_size  btc_n_orphaned_blocks  \
# 0              0.0            0.000235                      0
# 1              0.0            0.000241                      0
# 2              0.0            0.000228                      0
# 3              0.0            0.000218                      0
# 4              0.0            0.000234                      0
#
#    btc_n_transactions_per_block  btc_median_confirmation_time  btc_hash_rate  \
# ...

# %% [markdown]
# ## Numerical Data Distribution:
# Next,we perform the distribution of all features by plotting them for analysis:

# %%
btcoin_df_num.hist(figsize=(24, 30), bins=50, xlabelsize=8, ylabelsize=8);

# %%
#this is assertion block which verifies the solution.

try:
    def verify_answer():
           return True

    ref_assert_var = verify_answer()
except Exception as e:
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')

# %% [markdown]
# ## Regression:
#
# The linear regression library has convenient ways to specify parameters for regression and hence is popularly used.
# The main parameters of linear regression are the intecept and the coefficients.
#
# The most important parameter to look for is the mean squared error, which tells us how good the predictions matched the ground truth or the target variable.
#
# ### References:
# https://refactored.ai/user/rf636/notebooks/courses/reg-journey.ipynb?track=11&type=course#

# %%
from sklearn import linear_model
X = btcoin_df[['btc_market_price']]
y = btcoin_df.btc_market_cap 
lr_model = linear_model.LinearRegression()

# %% [markdown]
# Here we observe that the plots-btc_difficulty,btc_marketprice,btc_marketcap and btc_hash rate have a similar kind of distribution.Same is the case with btc_n_transcations_total and btc_n_unique_addresses.

# %%
lr_model.fit(X, Y)
pred = lr_model.predict(X)
print ('Residual sum of squares: %.2f' % np.mean((lr_model.predict(X)- y) ** 2))
# Out:
# Residual sum of squares Train: 649609887287268096.00

# %%
#this is assertion block which verifies the solution.

try:
    def verify_answer():
        return True

    ref_assert_var = verify_answer()
except Exception as e:
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')

# %% [markdown]
# After importing the library file required for performing 'Linear Regression',we now try to find the best fit of market price and market capital,i.e., total value of bitcoins in circulation.

# %%
ax = btcoin_df.plot(kind='scatter', x='btc_market_price', y='btc_market_cap', color='black', figsize=(14,10))
ax.plot(X, pred, color='blue')  
ax.plot(X, X*lr_model.coef_ + lr_model.intercept_+ 100, linestyle='--', color='yellow')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-7b1de2fa4e33> in <module>()
#       1 ax = btcoin_df.plot(kind='scatter', x='btc_market_price', y='btc_market_cap', color='black', figsize=(14,10))
# ----> 2 ax.plot(X, pred, color='blue')
#       3 ax.plot(X, X*lr_model.coef_ + lr_model.intercept_+ 100, linestyle='--', color='yellow')
#
# NameError: name 'pred' is not defined

# %% [markdown]
# We have drawn a scatter plot between the parameters-btc_market_price and btc_market_cap,find the best fit and later predict the mean square error

# %%
#this is assertion block which verifies the solution.

try:
    def verify_answer():
        return True
    ref_assert_var = verify_answer()
except Exception as e:
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y, pred)
# Out:
# 6.496098872872681e+17

# %% [markdown]
# Plotting the results

# %%
# plotting result
y_df = pd.DataFrame(y)
y_df['pred'] = pred
y_df['err'] = y_df.pred - y
(y_df
 .plot(figsize=(14,10))
)

# %%
Bitcoin Market Analysis:

# %%
btcoin_df.plot(grid=True, figsize=(20, 10)).axhline(y = 1, color = "black", lw = 2)
