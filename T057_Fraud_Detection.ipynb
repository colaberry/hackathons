# %% [markdown]
# Fraud is the event of illegal access or execution of a transaction. Fraud modeling is the process where large amounts of transactional data is analyzed to identify observations which do not generally follow the regular patterns. Due to this nature of the problem, anamoly detection and some classification techniques are most suited to analyze such problems and draw valuable insights.
#
#
# A company Alpha solutions provides fraud detection products, solutions and services to financial businesses. One such financial client has many credit card transactions that are provided as the training data. They want the Financial Data Scientist to build models using the available training data.
#
#
# Ingest the data into a format that is easy for analysis.
# Perform Exploratory Data Analysis on the dataset.
# Perform classification on the dataset to detect fraud ( logistic regression, naive bayes classifier etc).

# %%
#import NumPy library
#NumPy is a library in Python that supports large, multidimensional arrays and matrices.
#It facilitates scientific computing with high level mathematical functions to operate on these arrays.


#import pandas  library
#Pandas is an open source library that provides easy-to-use data structures and data analysis tools in Python. 
#This library offers a very useful data structure called the Dataframes.
#Ref: http://pandas.pydata.org

#import matplotlib library
#This library is used to plot histograms and heatplots and plotting variety of graphs it's a visualisation library.

#import seaborn library
#For statistical data visualisation.For informative statistical graphics.

# use scikit Learn/sklearn : For machine learning built on NumPy, SciPy, matplotlib, this library contains machine 
#learning models for classification, regression and clustering.


#use logisticRegression method to predict values.

import numpy as py
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
fdata = pd.read_csv('https://raw.githubusercontent.com/colaberry/data/master/Fraud/fraud_data.csv')
fdata.head()
fdata.info()
fdata.describe()
sns.set_style('whitegrid')
fdata['A'].hist(bins=30)
plt.xlabel('A')
fdata['F'].hist(bins=30)
fdata['J'].hist(bins=30)
sns.jointplot(x='A',y='J',data=fdata)
sns.jointplot(x='F',y='J',data=fdata)
sns.jointplot(x='F',y='G',data=fdata,color='red')
sns.jointplot(x='S',y='J',data=fdata)
sns.pairplot(fdata,hue='F',palette='bwr')
from sklearn.model_selection import train_test_split
X = fdata[['S', 'A', 'J','G']]
y = fdata['F']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
from sklearn.linear_model import LogisticRegression
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
predictions = logmodel.predict(X_test)
from sklearn.metrics import classification_report
print(classification_report(y_test,predictions))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 5 columns):
# S    10000 non-null int64
# A    10000 non-null int64
# F    10000 non-null int64
# J    10000 non-null int64
# G    10000 non-null int64
# dtypes: int64(5)
# memory usage: 390.7 KB
#              precision    recall  f1-score   support
#
#           0       0.67      0.94      0.79       344
#           1       0.99      0.95      0.97      2956
#
# avg / total       0.96      0.95      0.95      3300

# %% [markdown]
# hint
#
# To read the data set use command pd.read_csv and assign it to a variable fdata
#
# use .head() to list the top rows
#
# use sns.jointplot() to visualise the comparision between two categories
#
# import train_test_split from sklearn.model_selection to train the dataset
#
#  import LogisticRegression from sklearn.linear_model

# %%
import numpy as py
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
fdata = pd.read_csv('https://raw.githubusercontent.com/colaberry/data/master/Fraud/fraud_data.csv')
fdata.head()
fdata.info()
fdata.describe()
sns.set_style('whitegrid')
fdata['A'].hist(bins=30)
plt.xlabel('A')
fdata['F'].hist(bins=30)
fdata['J'].hist(bins=30)
sns.jointplot(x='A',y='J',data=fdata)
sns.jointplot(x='F',y='J',data=fdata)
sns.jointplot(x='F',y='G',data=fdata,color='red')
sns.jointplot(x='S',y='J',data=fdata)
sns.pairplot(fdata,hue='F',palette='bwr')
from sklearn.model_selection import train_test_split
X = fdata[['S', 'A', 'J','G']]
y = fdata['F']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
from sklearn.linear_model import LogisticRegression
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
predictions = logmodel.predict(X_test)
from sklearn.metrics import classification_report
print(classification_report(y_test,predictions))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 5 columns):
# S    10000 non-null int64
# A    10000 non-null int64
# F    10000 non-null int64
# J    10000 non-null int64
# G    10000 non-null int64
# dtypes: int64(5)
# memory usage: 390.7 KB
#              precision    recall  f1-score   support
#
#           0       0.67      0.94      0.79       344
#           1       0.99      0.95      0.97      2956
#
# avg / total       0.96      0.95      0.95      3300
