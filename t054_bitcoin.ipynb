# %% [markdown]
# Bitcoin Price Analysis
#
# Bitcoin is a cryptocurrency and worldwide payment system. It is the first decentralized digital currency, as the system works without a central bank or single administrator. The network is peer-to-peer and transactions take place between users directly, without an intermediary.
#
#   Bitcoin was invented by an unknown person or group of people under the name Satoshi Nakamoto. As of February 2015, over 100,000 merchants and vendors accepted bitcoin as payment. Research produced by the University of Cambridge estimates that in 2017, there were 2.9 to 5.8 million unique users using a cryptocurrency wallet, most of them using bitcoin.
#
#   In this challenge, we ask you to complete the analysis of what would be future market values for bitcoin. In particular, we ask you to apply the tools of machine learning to predict the future market price based on historical data provided.
#
#   Data is divided into two sets-training and testing

# %%
test_data="https://raw.githubusercontent.com/colaberry/data/master/Bitcoin/test_set.csv"
train_data="https://raw.githubusercontent.com/colaberry/data/master/Bitcoin/bitcoin_dataset.csv"

# %% [markdown]
# To work with the  data we need some of the packages.Such as -
# pandas,
# numpy,
# seaborn,
# matplotlib ...
# Few of them are imported as follows.

# %%
import pandas as pd
import numpy as np
import matplotlib as mp

# %%
import seaborn as s
train_data="https://raw.githubusercontent.com/colaberry/data/master/Bitcoin/bitcoin_dataset.csv"
df=pd.read_csv(train_data)
df.head()  # here head() is used to print total number of rows and columns
# Out:
#         Date  btc_market_price  btc_total_bitcoins  btc_market_cap  \
# 0  2/17/2010               0.0           2043200.0             0.0
# 1  2/18/2010               0.0           2054650.0             0.0
# 2  2/19/2010               0.0           2063600.0             0.0
# 3  2/20/2010               0.0           2074700.0             0.0
# 4  2/21/2010               0.0           2085400.0             0.0
#
#    btc_trade_volume  btc_blocks_size  btc_avg_block_size  \
# 0               0.0              0.0            0.000235
# 1               0.0              0.0            0.000241
# 2               0.0              0.0            0.000228
# 3               0.0              0.0            0.000218
# 4               0.0              0.0            0.000234
#
#    btc_n_orphaned_blocks  btc_n_transactions_per_block  \
# 0                      0                           1.0
# 1                      0                           1.0
# ...

# %% [markdown]
# Let us now look at market price in graphical plots

# %%
s.distplot(df['btc_market_price'])

# %% [markdown]
# The graph can be plotted between various attributes by the following means:

# %%
for i in range(0, len(df.columns), 5):
    sns.pairplot(data=df,
                x_vars=df.columns[i:i+5],
                y_vars=['btc_market_price'])

# %% [markdown]
# Linear Regression:
#   To operating on datasets we need to create dataframes which can be done using pandas library.Linear models are build to predict the future market price accurately.
#   lm is for linear model,
#   lm.summary() is used to print the entire datamodel after liner regression.
