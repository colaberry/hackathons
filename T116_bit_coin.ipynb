# %% [markdown]
# # Problem 1: Bitcoin Price Analysis
#
#
# ### Historic price of bitcoins are provided for analysis. Your task is to
#
# (1)Ingest the data into a format that is easy for analysis.
# (2)Perform Exploratory Data Analysis on the dataset.
# (3)Can you predict the future price of the dataset?
#
# ### Exercise:
#    Draw a factor graph

# %%
#some initial code here, to help start the user.

import pandas as pd

#table

sal=pd.read_csv('https://raw.githubusercontent.com/colaberry/data/master/Bitcoin/bitcoin_dataset.csv')
sal.head(2906)
# Out:
#            Date  btc_market_price  btc_total_bitcoins  btc_market_cap  \
# 0     2/17/2010           0.00000           2043200.0    0.000000e+00
# 1     2/18/2010           0.00000           2054650.0    0.000000e+00
# 2     2/19/2010           0.00000           2063600.0    0.000000e+00
# 3     2/20/2010           0.00000           2074700.0    0.000000e+00
# 4     2/21/2010           0.00000           2085400.0    0.000000e+00
# 5     2/22/2010           0.00000           2098150.0    0.000000e+00
# 6     2/23/2010           0.00000           2110700.0    0.000000e+00
# 7     2/24/2010           0.00000           2120200.0    0.000000e+00
# 8     2/25/2010           0.00000           2127600.0    0.000000e+00
# 9     2/26/2010           0.00000           2136100.0    0.000000e+00
# 10    2/27/2010           0.00000           2144750.0    0.000000e+00
# 11    2/28/2010           0.00000           2152850.0    0.000000e+00
# ...

# %% [markdown]
# #### this is the hint block, use code cell or markdown cell, but remember it wont get executed, so better go with markdown.
#
# Use '=' operator to create and assign value to variable.
# use read_csv function

# %%
#this is assertion block which verifies the solution. 
import numpy as np
try:
    def verify_answer():
        """
        enter your verification code here.
        return true if your checks pass
        eg: 
        if above_user_answer_var > 100: 
            return True
        else:
            return False
        """
        if any(sal!=0):
            return True
        else:
            return False

    ref_assert_var = verify_answer()
except Exception as e: 
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')
# Out:
# continue

# %% [markdown]
# # Functional method for plotting

# %%
# this is the answer block, always use the code cell.
import pandas as pd
import numpy as np

# Create Figure (empty canvas)
fig = plt.figure()

# Add set of axes to figure
axes1 = fig.add_axes([0.1, 0.1, 1, 0.8]) # left, bottom, width, height (range 0 to 1)
x=sal.btc_total_bitcoins
y=sal.btc_output_volume
z=sal.btc_avg_block_size

axes2 = fig.add_axes([0.2, 0.5,0.4, 0.3]) 



axes1.plot(x, y, 'b')
axes2.plot(y, z, 'r')
axes1.set_xlabel('btc_total_bitcoins') # Notice the use of set_ to begin methods
axes1.set_ylabel('btc_output_volume')
axes1.set_title('graph1')

axes2.set_ylabel('btc_avg_block_size') # Notice the use of set_ to begin methods
axes2.set_xlabel('btc_output_volume')
axes2.set_title('graph2')

# %% [markdown]
# hint:    use axes.plot(x,y,'color')

# %%
#this is assertion block which verifies the solution.

try:
    def verify_answer():
        """
        enter your verification code here.
        return true if your checks pass
        eg: 
        if above_user_answer_var > 100: 
            return True
        else:
            return False
        """
        if any(x!=y):
            return True
        else:
            return False

    ref_assert_var = verify_answer()
except Exception as e: 
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')
# Out:
# continue

# %% [markdown]
# ##### scatter plotting

# %%
#scatter plot

plt.scatter(x,y)

# %% [markdown]
# hint:
#
# use scatter()

# %%
#this is assertion block which verifies the solution.

try:
    def verify_answer():
        """
        enter your verification code here.
        return true if your checks pass
        eg: 
        if above_user_answer_var > 100: 
            return True
        else:
            return False
        """
        if any(x!=y):
            return True
        else:
            return False

    ref_assert_var = verify_answer()
except Exception as e: 
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')
# Out:
# continue

# %% [markdown]
# ## scatter plotting

# %%
#scatter plot
import matplotlib
import matplotlib.pyplot as plt
btc_trace=matplotlib.pyplot.scatter(x=sal.index,y=sal['btc_market_price'])
plt

# %% [markdown]
# hint
#
# use matplotlib.pyplot.scatter(x=sal.index,y=sal['btc_market_price'])

# %%
#this is assertion block which verifies the solution.

try:
    def verify_answer():
        """
        enter your verification code here.
        return true if your checks pass
        eg: 
        if above_user_answer_var > 100: 
            return True
        else:
            return False
        """
        if any(x!=y):
            return True
        else:
            return False

    ref_assert_var = verify_answer()
except Exception as e: 
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')
# Out:
# continue

# %% [markdown]
# # # box plotting

# %%
#box.plot

ax=sns.boxplot(data=sal['btc_market_price'],orient="v")

# %% [markdown]
# hint
# use ax=sns.boxplot(data=sal['btc_market_price'],orient="v")

# %%
#this is assertion block which verifies the solution.

try:
    def verify_answer():
        """
        enter your verification code here.
        return true if your checks pass
        eg: 
        if above_user_answer_var > 100: 
            return True
        else:
            return False
        """
        if any(x!=y):
            return True
        else:
            return False

    ref_assert_var = verify_answer()
except Exception as e: 
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')
# Out:
# continue

# %% [markdown]
# ## Violin plotting

# %%
#Violin Plot
sns.violinplot(x='Date',y='btc_market_price',data=sal)

# %% [markdown]
# hint
#
# use
#
# sns.violinplot(x='Date',y='btc_market_price',data=sal)

# %%
#this is assertion block which verifies the solution.

try:
    def verify_answer():
        """
        enter your verification code here.
        return true if your checks pass
        eg: 
        if above_user_answer_var > 100: 
            return True
        else:
            return False
        """
        if any(x!=y):
            return True
        else:
            return False

    ref_assert_var = verify_answer()
except Exception as e: 
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')
# Out:
# continue

# %% [markdown]
# ## factor plot

# %%
#Factor plot
sns.factorplot(x='Date',y='btc_market_price',data=sal,kind='bar')

# %%
hint

use
sns.factorplot(x='Date',y='btc_market_price',data=sal,kind='bar')

# %%
#this is assertion block which verifies the solution.

try:
    def verify_answer():
        """
        enter your verification code here.
        return true if your checks pass
        eg: 
        if above_user_answer_var > 100: 
            return True
        else:
            return False
        """
        if any(x!=y):
            return True
        else:
            return False

    ref_assert_var = verify_answer()
except Exception as e: 
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')
# Out:
# continue

# %% [markdown]
# ## strip plotting

# %%
#strip plot
sns.stripplot(x="btc_total_bitcoins",y="btc_market_price",data=sal)

# %% [markdown]
# hint
#
# use
#
# sns.stripplot(x="btc_total_bitcoins",y="btc_market_price",data=sal)

# %%
#this is assertion block which verifies the solution.

try:
    def verify_answer():
        """
        enter your verification code here.
        return true if your checks pass
        eg: 
        if above_user_answer_var > 100: 
            return True
        else:
            return False
        """
        if any(x!=y):
            return True
        else:
            return False

    ref_assert_var = verify_answer()
except Exception as e: 
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')
# Out:
# continue

# %%
#prediction
import statsmodels.formula.api as sm

from sklearn.metrics import mean_squared_error
lm=sm.ols(formula='btc_trade_volume ~ btc_market_price', data=sal).fit()
y_hat=lm.predict(sal[['btc_market_price']])
mse_lm=mean_squared_error(y_hat,sal[['btc_market_price']])
print("Mean:",mse_lm)
print("Prediction:")
print(y_hat)
# Out:
# Mean: 6.94969335261e+16
# Prediction:
# 0      -1.862365e+07
# 1      -1.862365e+07
# 2      -1.862365e+07
# 3      -1.862365e+07
# 4      -1.862365e+07
# 5      -1.862365e+07
# 6      -1.862365e+07
# 7      -1.862365e+07
# 8      -1.862365e+07
# 9      -1.862365e+07
# 10     -1.862365e+07
# 11     -1.862365e+07
# 12     -1.862365e+07
# 13     -1.862365e+07
# 14     -1.862365e+07
# 15     -1.862365e+07
# 16     -1.862365e+07
# 17     -1.862365e+07
# 18     -1.862365e+07
# 19     -1.862365e+07
# 20     -1.862365e+07
# 21     -1.862365e+07
# 22     -1.862365e+07
# 23     -1.862365e+07
# 24     -1.862365e+07
# 25     -1.862365e+07
# 26     -1.862365e+07
# 27     -1.862365e+07
# 28     -1.862365e+07
# 29     -1.862365e+07
#             ...
# 2876    1.629764e+09
# 2877    1.634972e+09
# 2878    1.651020e+09
# 2879    1.867947e+09
# 2880    1.883884e+09
# 2881    1.810534e+09
# 2882    1.658331e+09
# 2883    1.597732e+09
# 2884    1.643006e+09
# 2885    1.442024e+09
# ...

# %% [markdown]
# hint:
# use lm.predict()
