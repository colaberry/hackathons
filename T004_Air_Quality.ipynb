# %% [markdown]
# ##Problem 3.0 Air Quality Analysis
#
# ###All of this data comes from EPA’s Air Quality System (AQS). Data collection agencies report their data to EPA via this system and it calculates several types of aggregate (summary) data for EPA internal use. This includes daily and annual summaries, but not monthly summaries, as these are not routinely needed by EPA.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# Read the data and print

# %% [markdown]
# #Hint: Use read_csv() function to read the csv file

# %%
#Solution :
grad_url = "https://raw.githubusercontent.com/colaberry/data/master/8hour_42101_2017_10K.csv"
pr_df= pd.read_csv(grad_url)
pr_df.head()

# %%
#this is assertion block which verifies the solution.
import pandas as pd
import numpy as np
import seaborn as sns

grad_url = "https://raw.githubusercontent.com/colaberry/data/master/8hour_42101_2017_10K.csv"
pr_df= pd.read_csv(grad_url)
pr_df
# Out:
#       State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0              1           73        23           42101    2  33.553056
# 1              1           73        23           42101    2  33.553056
# 2              1           73        23           42101    2  33.553056
# 3              1           73        23           42101    2  33.553056
# 4              1           73        23           42101    2  33.553056
# 5              1           73        23           42101    2  33.553056
# 6              1           73        23           42101    2  33.553056
# 7              1           73        23           42101    2  33.553056
# 8              1           73        23           42101    2  33.553056
# 9              1           73        23           42101    2  33.553056
# 10             1           73        23           42101    2  33.553056
# 11             1           73        23           42101    2  33.553056
# ...

# %% [markdown]
# ### Now plot the graph

# %%
# Write the code

# %% [markdown]
# #Hint: plot the graph using distplot() function

# %%
#Solution
sns.distplot(pr_df['Mean Including All Data'])
