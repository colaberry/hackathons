# %% [markdown]
# # Bitcoin Price analysis
#
# Historic price of bitcoins are provided for analysis.This dataset consistes of 23 rows.
#
# ### Problem Statement:
# Bitcoin is a cryptocurrency and worldwide payment system.It is the first decentralized digital currency, as the system works without a central bank or single administrator.
# The aim of this analysis is to visualize the data set on a time axis to analyze and predict the market price of bitcoin . Plotting the graphs help us to find the factors on which the price is dependent.
#
# ## Exercise:
# Reading into data frame:
# Dataframes are a part of the library called Pandas. One of the versatile features of pandas dataframe is that, it can read the data by just specifying the link in the read_csv() function.
# The dataset can be found in the url:https://raw.githubusercontent.com/colaberry/data/master/Bitcoin/bitcoin_dataset.csv
# List first few rows of the bit_set dataframe using the .head() function and assign it to bit_sample. How many rows does the .head() show up?

# %%
import pandas as pd
url="https://raw.githubusercontent.com/colaberry/data/master/Bitcoin/bitcoin_dataset.csv"
bit_set=pd.read_csv(url)
bit_sample=bit_set.head()

# %% [markdown]
# Use read_csv(url) and head() function

# %%
import numpy as np

# %%
try:
    def verify_answer():
        if (url=="https://raw.githubusercontent.com/colaberry/data/master/Bitcoin/bitcoin_dataset.csv"): 
            return True
        else:
            return False
        

    ref_assert_var = verify_answer()
except Exception as e:
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')
# Out:
# continue

# %% [markdown]
# #  Data Analysis
#
# Here, we develop graphical representations of market price variation with various columns.
#
# ## Scatter Plots or Joint plots using seaborn
# To visualize how each factor would affect market price, we can run a scatter plot of the market price for each dependent variable. This will help visualize how the target vector may be affected by each factor. Later we shall study quantitave methods that can provide us methods to measure how each factor affects the output or if it doesnt affect the output at all.
#
# g = sns.jointplot("btc_market_price", "btc_market_capital", data=bit_set, color="g", size=7)
#
# ![linear.JPG](attachment:linear.JPG)
#
#
#
#
# # # Exercise:
# Use jointplot to plot a graph between hash rate and market price and assign it to g.Print g

# %%
import seaborn as sns
g = sns.jointplot("btc_market_price", "btc_hash_rate", data=bit_set, color="g", size=7)

# %% [markdown]
# import seaborn

# %%
import pandas as pd
from sklearn import datasets, linear_model
import statsmodels.formula.api as sm
url="https://raw.githubusercontent.com/colaberry/data/master/Bitcoin/bitcoin_dataset.csv"
bit_set=pd.read_csv(url)

# %%
try:
    def verify_answer():
        if (g): 
            return True
        else:
            return False
        

    ref_assert_var = verify_answer()
except Exception as e:
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')
# Out:
# continue

# %% [markdown]
# #  Regression Using Statsmodels
# Statsmodels is a library used widely for linear regression. The linear regression library has convenient ways to specify parameters for regression and hence is popularly used. The format to specify regression for a single variable is:
#
# lm = sm.ols(formula = 'y ~ x')
# where x is a dependent variable. Let us look at how market Price is affected by difficulty.
#
# lm = sm.ols(formula='btc_market_price ~'btc_difficulty ', data=bit_set).fit()
# This is called simple regression as only one variable affects the target variable.
#
# To get prediction from the trained model:
#
# y_hat = lm.predict(bit_set['btc_difficulty'])
#
#
# The most important parameter to look for is the mean squared error, which tells us how good the predictions matched the ground truth or the target variable.
#
# print("MSE:", mean_squared_error(bit_set['btc_market_price'].values, y_hat))
# The lesser is the MSE the more accurate your answer.
# ## Exercise:
# now try to predict the market price for columns btc_difficulty,date and btc_market_cap and find the MSE,store it in m.

# %%
from sklearn.metrics import mean_squared_error
import statsmodels.formula.api as sm
url="https://raw.githubusercontent.com/colaberry/data/master/Bitcoin/bitcoin_dataset.csv"
bit_set=pd.read_csv(url)
bit_set.fillna(value=0,inplace=True)
lm=sm.ols(formula='btc_market_price~Date+btc_difficulty+btc_market_cap',data=bit_set).fit()
y=lm.predict(bit_set[['Date','btc_difficulty','btc_market_cap']])
m=mean_squared_error(bit_set['btc_market_price'].values,y)
print(m)
# Out:
# 0.530445807515

# %% [markdown]
# hint:

# %%
from sklearn import datasets,linear_model
from matplotlib import rcParams
from sklearn.metrics import mean_squared_error
import pandas as pd
import numpy as np
import seaborn as sns

# %%
try:
    def verify_answer():
        if (m>0.5): 
            return True
        else:
            return False
        

    ref_assert_var = verify_answer()
except Exception as e:
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')
# Out:
# continue

# %% [markdown]
# # Heat map
# Improving the fit - Multicollinearity
# Many times, more than one input could be dependent on each other. In Linear Regression, the requirement is that all the input variables are independent of each other. When a feature is dependent on one or more of the other input features, it leads to a phenomenon known as multi-collinearity or correlation. This can be visualized by a heat map which shows the correlation between all the features. In the housing data, the heat map can be visualized by first calculating the correlation value.
#
# correlations = bit_set.corr()
# correlations
# This displays the matrix of correlation values. Values closer to 1.0 show high correlation between the features and those closer to 0.0 otherwise.
# now,heatmap:
# sns.heatmap(c,linewidths=1)
#
# ![heap%20table.JPG](attachment:heap%20table.JPG)
#
# whereever the correlation is high, we must not include only one of the column to make model.
#
# ## Exercise:
# print heatmap and also print rsquared value using variable r_squared.

# %%
r_squared = lm.rsquared
c=bit_set.corr()
print(r_squared)
sns.heatmap(c,linewidths=1)
# Out:
# 0.999999900124

# %% [markdown]
# hint:

# %%
from sklearn import datasets,linear_model
from matplotlib import rcParams
from sklearn.metrics import mean_squared_error
import statsmodels.formula.api as sm
import pandas as pd
import numpy as np
import seaborn as sns

# %%
try:
    def verify_answer():
        if (r_squared>0.99999): 
            return True
        else:
            return False
        

    ref_assert_var = verify_answer()
except Exception as e:
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')
# Out:
# continue

# %% [markdown]
# # Removing extra columns
#
# Based on the above heatmap, we can eliminate few columns whose correlation values are greater than .7 which are shown in dark colours.
#
# sample code:
# from sklearn import datasets,linear_model
# from matplotlib import rcParams
# from sklearn.metrics import mean_squared_error
# import statsmodels.formula.api as sm
# import pandas as pd
# import numpy as np
# import seaborn as sns
#
#
# url="https://raw.githubusercontent.com/colaberry/data/master/Bitcoin/bitcoin_dataset.csv"
# find=pd.read_csv(url)
# find.fillna(value=0,inplace=True)
# lm=sm.ols(formula='btc_market_price~Date+btc_median_confirmation_time+btc_cost_per_transaction+btc_n_transactions_per_block+btc_transaction_fees+btc_miners_revenue+btc_output_volume+btc_hash_rate+btc_market_cap+btc_blocks_size+btc_total_bitcoins+btc_trade_volume',data=find).fit()
# y=lm.predict(find[['Date','btc_cost_per_transaction','btc_estimated_transaction_volume_usd','btc_median_confirmation_time','btc_transaction_fees','btc_n_transactions_per_block','btc_hash_rate','btc_miners_revenue','btc_output_volume','btc_market_cap','btc_blocks_size','btc_trade_volume','btc_total_bitcoins']])
# print(mean_squared_error(find['btc_market_price'].values,y))
# c=find.corr()
# sns.heatmap(c,linewidths=1)
#
# here the value of MSE is
# 1.40840035166e-06
#
# # Exercise:
# can you find rsquared,if so then print it using r_squared

# %%
llm=sm.ols(formula='btc_market_price~Date+btc_median_confirmation_time+btc_cost_per_transaction+btc_n_transactions_per_block+btc_transaction_fees+btc_miners_revenue+btc_output_volume+btc_hash_rate+btc_market_cap+btc_blocks_size+btc_total_bitcoins+btc_trade_volume',data=bit_set).fit()
y=llm.predict(bit_set[['Date','btc_cost_per_transaction','btc_estimated_transaction_volume_usd','btc_median_confirmation_time','btc_transaction_fees','btc_n_transactions_per_block','btc_hash_rate','btc_miners_revenue','btc_output_volume','btc_market_cap','btc_blocks_size','btc_trade_volume','btc_total_bitcoins']])
r_squared = lm.rsquared
print(r_squared)
# Out:
# 0.999999900124
#
# Done

# %% [markdown]
# hint: lm.rsquared

# %%
from sklearn import datasets,linear_model
from matplotlib import rcParams
from sklearn.metrics import mean_squared_error
import statsmodels.formula.api as sm
import pandas as pd
import numpy as np
import seaborn as sns
