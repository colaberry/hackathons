# %%
import numpy as np
import pandas as pd 



import math
#import scikit as sk
import matplotlib.pyplot as plt
# %matplotlib inline

df= pd.read_csv("https://raw.githubusercontent.com/colaberry/data/master/Fraud/fraud_data.csv")

# %%
df
# Out:
#       S  A  F  J  G
# 0     0  2  1  0  1
# 1     0  0  1  0  1
# 2     0  2  1  0  1
# 3     0  1  1  0  1
# 4     0  2  0  1  1
# 5     0  1  1  0  1
# 6     0  1  0  1  1
# 7     1  1  1  1  1
# 8     1  2  1  0  1
# 9     1  0  1  0  0
# 10    0  1  0  1  0
# 11    1  1  1  0  1
# 12    1  1  0  1  1
# 13    0  0  1  0  1
# 14    1  1  1  0  1
# 15    1  1  0  1  0
# 16    0  1  1  1  1
# 17    0  2  1  0  1
# 18    0  1  1  0  1
# 19    1  0  1  0  1
# 20    0  1  1  0  1
# 21    0  2  1  0  1
# 22    0  0  1  1  1
# 23    0  0  1  0  1
# 24    0  1  1  0  1
# 25    1  0  0  1  0
# 26    0  1  0  1  1
# 27    1  2  1  0  1
# 28    0  2  1  0  1
# 29    0  1  1  0  1
# ...  .. .. .. .. ..
# 9970  0  0  1  0  1
# 9971  0  2  1  0  1
# 9972  0  1  1  0  1
# 9973  1  1  1  0  1
# 9974  1  1  1  0  1
# 9975  0  2  1  0  1
# 9976  1  1  1  0  1
# 9977  1  2  0  1  1
# 9978  0  0  1  0  1
# 9979  1  2  1  0  1
# 9980  0  0  1  0  1
# 9981  0  1  1  0  1
# 9982  1  1  1  0  1
# 9983  1  1  1  0  1
# 9984  1  2  1  0  1
# 9985  1  0  1  0  1
# 9986  1  1  1  0  1
# 9987  0  1  1  0  1
# 9988  1  2  1  0  1
# 9989  0  1  0  1  1
# 9990  0  1  1  0  1
# 9991  0  2  0  1  1
# 9992  0  0  1  0  1
# 9993  0  0  0  1  1
# 9994  0  1  1  0  1
# 9995  0  0  0  1  1
# 9996  1  0  1  0  1
# 9997  0  0  1  0  1
# 9998  1  2  1  1  1
# 9999  0  1  1  0  1
#
# [10000 rows x 5 columns]

# %%
#EDA
df.describe()
# Out:
#                   S             A             F             J             G
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       0.504200      1.099400      0.902600      0.137600      0.971000
# std        0.500007      0.772515      0.296516      0.344497      0.167815
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      1.000000      0.000000      1.000000
# 50%        1.000000      1.000000      1.000000      0.000000      1.000000
# 75%        1.000000      2.000000      1.000000      0.000000      1.000000
# max        1.000000      2.000000      1.000000      1.000000      1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 5 columns):
# S    10000 non-null int64
# A    10000 non-null int64
# F    10000 non-null int64
# J    10000 non-null int64
# G    10000 non-null int64
# dtypes: int64(5)
# memory usage: 390.7 KB

# %%
# Linear classifier in tensorflow

nv01= tf.feature_column.numeric_column('S')
nV02 = tf.feature_column.numeric_column('A')
nV03 = tf.feature_column.numeric_column('F')
nV04 = tf.feature_column.numeric_column('J')
nV05 = tf.feature_column.numeric_column('G')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-eff72d5a6734> in <module>()
#       1 # Linear classifier in tensorflow
#       2
# ----> 3 nv01= tf.feature_column.numeric_column('S')
#       4 nV02 = tf.feature_column.numeric_column('A')
#       5 nV03 = tf.feature_column.numeric_column('F')
#
# NameError: name 'tf' is not defined

# %%
features=[nV01,nV02,nV03,nV04,nV05]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-6f34a0900f13> in <module>()
# ----> 1 features=[nV01,nV02,nV03,nV04,nV05]
#
# NameError: name 'nV01' is not defined
