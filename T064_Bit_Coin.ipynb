# %% [markdown]
# ### Problem 1 : Bitcoin Price Analysis
#
# Historic price of bitcoins are provided for analysis. Your task is to
#
# 1)Ingest the data into a format that is easy for analysis.
# 2)Perform Exploratory Data Analysis on the dataset.
# 3)Can you predict the future price of the dataset?
#
#
# Data Description
# Bitcoin  data : https://github.com/colaberry/data/tree/master/Bitcoin
#
# Date : Date of observation
#
# btc_market_price : Average USD market price across major bitcoin exchanges.
#
# btc_total_bitcoins : The total number of bitcoins that have already been mined.
#
# btc_market_cap : The total USD value of bitcoin supply in circulation.
#
# btc_trade_volume : The total USD value of trading volume on major bitcoin exchanges.
#
# btc_blocks_size : The total size of all block headers and transactions.
#
# btc_avg_block_size : The average block size in MB.
#
# btc_n_orphaned_blocks : The total number of blocks mined but ultimately not attached to the main Bitcoin blockchain.
#
# btc_n_transactions_per_block : The average number of transactions per block.
#
# btc_median_confirmation_time : The median time for a transaction to be accepted into a mined block.
#
# btc_hash_rate : The estimated number of tera hashes per second the Bitcoin network is performing.
#
# btc_difficulty : A relative measure of how difficult it is to find a new block.
#
# btc_miners_revenue : Total value of coinbase block rewards and transaction fees paid to miners.
#
# btc_transaction_fees : The total value of all transaction fees paid to miners.
#
# btc_cost_per_transaction_percent : miners revenue as percentage of the transaction volume.
#
# btc_cost_per_transaction : miners revenue divided by the number of transactions.
#
# btc_n_unique_addresses : The total number of unique addresses used on the Bitcoin blockchain.
#
# btc_n_transactions : The number of daily confirmed Bitcoin transactions.
#
# btc_n_transactions_total : Total number of transactions.
#
# btc_n_transactions_excluding_popular : The total number of Bitcoin transactions, excluding the 100 most popular addresses.
#
# btc_n_transactions_excluding_chains_longer_than_100 : The total number of Bitcoin transactions per day excluding long transaction chains.
#
# btc_output_volume : The total value of all transaction outputs per day.
#
# btc_estimated_transaction_volume : The total estimated value of transactions on the Bitcoin blockchain.
#
#
# Steps involved in solving this problem
# - Preprocessing data: explore data, take care of missing data, check for categorical data(if there is any) and data scaling.
# - Train your dataset using all the linear regression models you've learned so far. If your model has a scaling parameter(s) use Grid Search to find the best scaling parameter. Use plots and graphs to help you get a better glimpse of the results.
# - Then check for mean square error
#
# ### Lets Start!!
# Let us first import pandas library which will help us perform access our data and operations on our data .
# Then let us assign the bitcoin dataset into dataSet variable.
#
# ### Import data
# import pandas as pd
# data = pd.read_csv('https://raw.githubusercontent.com/colaberry/data/master/Bitcoin/bitcoin_dataset.csv')
# test = pd.read_csv('https://raw.githubusercontent.com/colaberry/data/master/Bitcoin/test_set.csv')

# %%
#Import and read here
import pandas as pd
dataSet= pd.read_csv('https://raw.githubusercontent.com/colaberry/data/master/Bitcoin/bitcoin_dataset.csv')
test = pd.read_csv('https://raw.githubusercontent.com/colaberry/data/master/Bitcoin/test_set.csv')

# %% [markdown]
# #### this is the hint block, use code cell or markdown cell, but remember it wont get executed, so better go with markdown.
#
# Read the above code and utilise it!

# %%
# this is the answer block, always use the code cell.
import pandas as pd
dataSet= pd.read_csv('https://raw.githubusercontent.com/colaberry/data/master/Bitcoin/bitcoin_dataset.csv')
test = pd.read_csv('https://raw.githubusercontent.com/colaberry/data/master/Bitcoin/test_set.csv')

# %%
try:
    def verify_answer():
        return True
    ref_assert_var = verify_answer()
except Exception as e: 
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')

# %% [markdown]
# ### Preprocess data
#
# Lets explore our data and preprocess it with head() for viewing the first 5 values from the dataset and shape to know number of rows and columns in the table and print them

# %%
#Enter the preprocessing code here 

print(dataSet.head())
print(dataSet.shape)
# Out:
#         Date  btc_market_price  btc_total_bitcoins  btc_market_cap  \
# 0  2/17/2010               0.0           2043200.0             0.0
# 1  2/18/2010               0.0           2054650.0             0.0
# 2  2/19/2010               0.0           2063600.0             0.0
# 3  2/20/2010               0.0           2074700.0             0.0
# 4  2/21/2010               0.0           2085400.0             0.0
#
#    btc_trade_volume  btc_blocks_size  btc_avg_block_size  \
# 0               0.0              0.0            0.000235
# 1               0.0              0.0            0.000241
# 2               0.0              0.0            0.000228
# 3               0.0              0.0            0.000218
# 4               0.0              0.0            0.000234
#
#    btc_n_orphaned_blocks  btc_n_transactions_per_block  \
# 0                      0                           1.0
# 1                      0                           1.0
# ...

# %% [markdown]
# #### this is the hint block, use code cell or markdown cell, but remember it wont get executed, so better go with markdown.
# example data.head()
# data.shape

# %%
print(dataSet.head())
print(dataSet.shape)
# Out:
#         Date  btc_market_price  btc_total_bitcoins  btc_market_cap  \
# 0  2/17/2010               0.0           2043200.0             0.0
# 1  2/18/2010               0.0           2054650.0             0.0
# 2  2/19/2010               0.0           2063600.0             0.0
# 3  2/20/2010               0.0           2074700.0             0.0
# 4  2/21/2010               0.0           2085400.0             0.0
#
#    btc_trade_volume  btc_blocks_size  btc_avg_block_size  \
# 0               0.0              0.0            0.000235
# 1               0.0              0.0            0.000241
# 2               0.0              0.0            0.000228
# 3               0.0              0.0            0.000218
# 4               0.0              0.0            0.000234
#
#    btc_n_orphaned_blocks  btc_n_transactions_per_block  \
# 0                      0                           1.0
# 1                      0                           1.0
# ...

# %%
try:
    def verify_answer():
        return True
    ref_assert_var = verify_answer()
except Exception as e: 
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')
# Out:
# (2906, 24)

# %% [markdown]
# # EDA
# print info() of dataset and also describe() of data set for a complete EDA of the given dataset

# %%
print(data.info())
print(data.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2906 entries, 0 to 2905
# Data columns (total 24 columns):
# Date                                                   2906 non-null object
# btc_market_price                                       2906 non-null float64
# btc_total_bitcoins                                     2879 non-null float64
# btc_market_cap                                         2906 non-null float64
# btc_trade_volume                                       2885 non-null float64
# btc_blocks_size                                        2877 non-null float64
# btc_avg_block_size                                     2906 non-null float64
# btc_n_orphaned_blocks                                  2906 non-null int64
# btc_n_transactions_per_block                           2906 non-null float64
# btc_median_confirmation_time                           2894 non-null float64
# btc_hash_rate                                          2906 non-null float64
# ...

# %%
#### this is the hint block, use code cell or markdown cell, but remember it wont get executed, so better go with markdown.
bull.info()
name.describe()

# %%
print(data.info())
print(data.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2906 entries, 0 to 2905
# Data columns (total 24 columns):
# Date                                                   2906 non-null object
# btc_market_price                                       2906 non-null float64
# btc_total_bitcoins                                     2879 non-null float64
# btc_market_cap                                         2906 non-null float64
# btc_trade_volume                                       2885 non-null float64
# btc_blocks_size                                        2877 non-null float64
# btc_avg_block_size                                     2906 non-null float64
# btc_n_orphaned_blocks                                  2906 non-null int64
# btc_n_transactions_per_block                           2906 non-null float64
# btc_median_confirmation_time                           2894 non-null float64
# btc_hash_rate                                          2906 non-null float64
# ...

# %%
try:
    def verify_answer():
        return True
    ref_assert_var = verify_answer()
except Exception as e: 
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')

# %% [markdown]
# ### Addressing missing Data
# Now lets take care of missing data
# By using isnull() and sum() print the total missing data of each column

# %%
#Enter your code here 
num_missing = dataSet.isnull().sum()
num_missing[num_missing >0]
# Out:
# btc_total_bitcoins              27
# btc_trade_volume                21
# btc_blocks_size                 29
# btc_median_confirmation_time    12
# btc_difficulty                  16
# btc_transaction_fees            10
# dtype: int64

# %%
#### this is the hint block, use code cell or markdown cell, but remember it wont get executed, so better go with markdown.
example blah.isnull().sum()

# %%
num_missing = dataSet.isnull().sum()
num_missing[num_missing >0]
# Out:
# btc_total_bitcoins              27
# btc_trade_volume                21
# btc_blocks_size                 29
# btc_median_confirmation_time    12
# btc_difficulty                  16
# btc_transaction_fees            10
# dtype: int64

# %%
try:
    def verify_answer():
        return True
    ref_assert_var = verify_answer()
except Exception as e: 
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')

# %% [markdown]
# ### Filling the missing Data
# use the below method
# fillna(): return a copy of the data with missing values filled or imputed
# with ffill method to  a forward-fill to propagate the previous value forward
# and print it.

# %%
#enter your code here 
data_new = dataSet.fillna(method='ffill')
print(data_new)
# Out:
#            Date  btc_market_price  btc_total_bitcoins  btc_market_cap  \
# 0     2/17/2010           0.00000           2043200.0    0.000000e+00
# 1     2/18/2010           0.00000           2054650.0    0.000000e+00
# 2     2/19/2010           0.00000           2063600.0    0.000000e+00
# 3     2/20/2010           0.00000           2074700.0    0.000000e+00
# 4     2/21/2010           0.00000           2085400.0    0.000000e+00
# 5     2/22/2010           0.00000           2098150.0    0.000000e+00
# 6     2/23/2010           0.00000           2110700.0    0.000000e+00
# 7     2/24/2010           0.00000           2120200.0    0.000000e+00
# 8     2/25/2010           0.00000           2127600.0    0.000000e+00
# 9     2/26/2010           0.00000           2136100.0    0.000000e+00
# 10    2/27/2010           0.00000           2144750.0    0.000000e+00
# 11    2/28/2010           0.00000           2152850.0    0.000000e+00
# ...

# %%
#### this is the hint block, use code cell or markdown cell, but remember it wont get executed, so better go with markdown.
example ouch.fillna(method='ffill')

# %%
data_new = dataSet.fillna(method='ffill')
print(data_new)
# Out:
#            Date  btc_market_price  btc_total_bitcoins  btc_market_cap  \
# 0     2/17/2010           0.00000           2043200.0    0.000000e+00
# 1     2/18/2010           0.00000           2054650.0    0.000000e+00
# 2     2/19/2010           0.00000           2063600.0    0.000000e+00
# 3     2/20/2010           0.00000           2074700.0    0.000000e+00
# 4     2/21/2010           0.00000           2085400.0    0.000000e+00
# 5     2/22/2010           0.00000           2098150.0    0.000000e+00
# 6     2/23/2010           0.00000           2110700.0    0.000000e+00
# 7     2/24/2010           0.00000           2120200.0    0.000000e+00
# 8     2/25/2010           0.00000           2127600.0    0.000000e+00
# 9     2/26/2010           0.00000           2136100.0    0.000000e+00
# 10    2/27/2010           0.00000           2144750.0    0.000000e+00
# 11    2/28/2010           0.00000           2152850.0    0.000000e+00
# ...

# %%
try:
    def verify_answer():
        return True
    ref_assert_var = verify_answer()
except Exception as e: 
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')

# %% [markdown]
# ### Scaling the Data for proper predictions
# Import MinMaxScaler from sklearn.preprocessing module.
# Assign the MinMaxScaler to scaler
# drop the Date,btc_market_price from data_new table and assign it to X
# and assign btc_market_price from data_new
# later import train_test_split from sklearn.model_selection module
# and Split the X,y witht the test_size of 20% into X_train_org, X_test_org, y_train, y_test using train_test_split.
# and fit_transform and scaled data to X_train and transform and scale  X_test_org to X_test

# %%
#enter your code here
# MinMaxScaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

X = data_new.drop(['Date','btc_market_price'], axis =1)
y = data_new['btc_market_price']

from sklearn.model_selection import train_test_split
X_train_org, X_test_org, y_train, y_test = train_test_split(X,y, test_size = 0.2,random_state = 20)

X_train = scaler.fit_transform(X_train_org)
X_test = scaler.transform(X_test_org)

# %%
#### this is the hint block, use code cell or markdown cell, but remember it wont get executed, so better go with markdown.
Please just see the answer

# %%
# MinMaxScaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

X = data_new.drop(['Date','btc_market_price'], axis =1)
y = data_new['btc_market_price']

from sklearn.model_selection import train_test_split
X_train_org, X_test_org, y_train, y_test = train_test_split(X,y, test_size = 0.2,random_state = 20)

X_train = scaler.fit_transform(X_train_org)
X_test = scaler.transform(X_test_org)
# Out:
# array([[  8.73058293e-01,   2.03853824e-02,   2.39243432e-02, ...,
#           1.04540122e-01,   6.93462504e-02,   3.20528780e-02],
#        [  9.58741389e-01,   5.17089712e-02,   1.29087671e-02, ...,
#           7.15526425e-02,   4.98713447e-02,   5.39039846e-02],
#        [  8.05337123e-01,   1.11243694e-02,   1.00069112e-02, ...,
#           2.73697637e-02,   3.97813996e-02,   1.07545459e-02],
#        ...,
#        [  9.39806127e-01,   3.19425804e-02,   3.88907085e-03, ...,
#           8.11287424e-02,   5.43414621e-02,   3.69204683e-02],
#        [  1.72942794e-01,   3.97978300e-06,   5.04992641e-07, ...,
#           3.62850534e-03,   5.95787957e-03,   1.74811529e-06],
#        [  9.50172319e-01,   4.07741786e-02,   1.22033180e-02, ...,
#           5.17687795e-02,   5.32679669e-02,   4.57573432e-02]])

# %%
try:
    def verify_answer():
        return True
    ref_assert_var = verify_answer()
except Exception as e: 
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')

# %% [markdown]
# ### Fitting the linear Regression
# Import LinearRegression from sklearn.linear_model
# Assign LinearRegression() to lr
# Fit the X_train and y_train to lr

# %%
#enter your code here
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#### this is the hint block, use code cell or markdown cell, but remember it wont get executed, so better go with markdown.
Please just see the answer

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
try:
    def verify_answer():
        return True
    ref_assert_var = verify_answer()
except Exception as e: 
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')

# %% [markdown]
# #### Predicting
# use predict() and pass X_test as parameter and assign it to y_pred
# and print the values
# and also check the mean_squared_error by importing  mean_squared_error as mse from sklearn.metrics
# and print it

# %%
# Out:
# [ -1.60326200e+00   2.43265143e+02   2.67618032e+02   1.44005926e+04
#    1.36178946e+02   1.35962010e+02   1.06417355e+03   4.32409730e+02
#   -3.05487014e+00   1.21559201e+01   7.90778447e+02   1.28335955e+01
#    1.72411742e+01   1.40183948e+01   1.04408784e+02   1.65923476e+04
#    1.96006860e+02   2.60999047e+02  -7.92178057e+00   1.20166326e+02
#    4.59014810e+02   1.11449511e+02  -6.01900420e+00   4.37955276e+02
#    2.25761504e+02   7.89409967e+00   6.09451530e+02  -3.14671867e+00
#    1.01947158e+01   2.55342801e+00  -1.70497950e+00   6.49519823e+01
#    2.54373034e+02   2.37120840e+03   4.30973853e+02   2.87825311e+02
#    5.09188957e+02   1.13533158e+04  -8.96377806e+00   9.70140644e+03
#    6.93832122e+03  -1.69848475e+00   7.40406816e+00   1.64025359e+02
#   -8.33772085e+00   4.14791895e+02  -4.13489579e+00  -6.53777915e+00
#    1.61493278e+01   6.47819202e+02   1.40077048e+04   5.69329428e+03
#    5.98685704e+02   4.33505827e+02  -6.28468842e-01   7.87219400e+00
# ...

# %%
#### this is the hint block, use code cell or markdown cell, but remember it wont get executed, so better go with markdown.
youAre.predict(able_test)
mse(truedata , predicted_data)

# %%
from sklearn.metrics import mean_squared_error as mse
ypred=lr.predict(X_test)
print(ypred)
mse(y_test,ypred)
# Out:
# [ -1.60326200e+00   2.43265143e+02   2.67618032e+02   1.44005926e+04
#    1.36178946e+02   1.35962010e+02   1.06417355e+03   4.32409730e+02
#   -3.05487014e+00   1.21559201e+01   7.90778447e+02   1.28335955e+01
#    1.72411742e+01   1.40183948e+01   1.04408784e+02   1.65923476e+04
#    1.96006860e+02   2.60999047e+02  -7.92178057e+00   1.20166326e+02
#    4.59014810e+02   1.11449511e+02  -6.01900420e+00   4.37955276e+02
#    2.25761504e+02   7.89409967e+00   6.09451530e+02  -3.14671867e+00
#    1.01947158e+01   2.55342801e+00  -1.70497950e+00   6.49519823e+01
#    2.54373034e+02   2.37120840e+03   4.30973853e+02   2.87825311e+02
#    5.09188957e+02   1.13533158e+04  -8.96377806e+00   9.70140644e+03
#    6.93832122e+03  -1.69848475e+00   7.40406816e+00   1.64025359e+02
#   -8.33772085e+00   4.14791895e+02  -4.13489579e+00  -6.53777915e+00
#    1.61493278e+01   6.47819202e+02   1.40077048e+04   5.69329428e+03
#    5.98685704e+02   4.33505827e+02  -6.28468842e-01   7.87219400e+00
# ...

# %%
try:
    def verify_answer():
        return True
    ref_assert_var = verify_answer()
except Exception as e: 
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')

# %% [markdown]
# # Predicting the Test dataset btc_market_price values
# drop Date from the test dataset and assign it to test_set
# take a new variable lr1 of LinearRegression() , fit X,y to it
# and assign y1pred variable with the predicted values of test_set and print y1pred

# %%
# Out:
# [ 9057.531406    8886.60230993  9073.68397229  8403.31554391  6764.97809031
#   7590.4153316   8073.6725488   8262.69256011  8556.55175089  8302.13345935
#   8358.97723399  8783.4335098   8563.37597992  9284.09335929]

# %%
#### this is the hint block, use code cell or markdown cell, but remember it wont get executed, so better go with markdown.
set=test.drop(['Date'], axis =1)
lr1 = LinearRegression()
lr1.fit(X,y)
y1pred=lr1.predict(test_set)

# %%
test_set=test.drop(['Date'], axis =1)
lr1 = LinearRegression()
lr1.fit(X,y)
y1pred=lr1.predict(test_set)
print(y1pred)
# Out:
# [ 9057.531406    8886.60230993  9073.68397229  8403.31554391  6764.97809031
#   7590.4153316   8073.6725488   8262.69256011  8556.55175089  8302.13345935
#   8358.97723399  8783.4335098   8563.37597992  9284.09335929]
