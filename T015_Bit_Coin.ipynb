# %% [markdown]
#
# # Bitcoin Price Analysis
#
# ## What is Bitcoin?
# - Bitcoin is a cryptocurrency and worldwide payment system. It is the first decentralized digital currency, as the system works without a central bank or single administrator.
# - Bitcoins are created as a reward for a process known as mining. They can be exchanged for other currencies, products, and services.
# -  Research produced by the University of Cambridge estimates that in 2017, there were 2.9 to 5.8 million unique users using a cryptocurrency wallet, most of them using bitcoin.
#
# ## About the Dataset
#    Harish Kashyap has shared a very extensive dataset historic price of bitcoins data originally provided by Bitcoin(BTC).The data was collected every other day since 2010 and daily since around 2018 over the span of 8 years.
#
#
#    The dataset consists of :
# - Date : Date of observation
# - btc_market_price : Average USD market price across major bitcoin exchanges.
# - btc_total_bitcoins : The total number of bitcoins that have already been mined.
# - btc_market_cap : The total USD value of bitcoin supply in circulation.
# - btc_trade_volume : The total USD value of trading volume on major bitcoin exchanges.
# - btc_blocks_size : The total size of all block headers and transactions.
# - btc_avg_block_size : The average block size in MB.
# - btc_n_orphaned_blocks : The total number of blocks mined but ultimately not attached to the main Bitcoin blockchain.
# - btc_n_transactions_per_block : The average number of transactions per block.
# - btc_median_confirmation_time : The median time for a transaction to be accepted into a mined block.
# - btc_hash_rate : The estimated number of tera hashes per second the Bitcoin network is performing.
# - btc_difficulty : A relative measure of how difficult it is to find a new block.
# - btc_miners_revenue : Total value of coinbase block rewards and transaction fees paid to miners.
# - btc_transaction_fees : The total value of all transaction fees paid to miners.
# - btc_cost_per_transaction_percent : miners revenue as percentage of the transaction volume.
# - btc_cost_per_transaction : miners revenue divided by the number of transactions.
# - btc_n_unique_addresses : The total number of unique addresses used on the Bitcoin blockchain.
# - btc_n_transactions : The number of daily confirmed Bitcoin transactions.
# - btc_n_transactions_total : Total number of transactions.
# - btc_n_transactions_excluding_popular : The total number of Bitcoin transactions, excluding the 100 most popular addresses.
# - btc_n_transactions_excluding_chains_longer_than_100 : The total number of Bitcoin transactions per day excluding long -transaction chains.
# - btc_output_volume : The total value of all transaction outputs per day.
# - btc_estimated_transaction_volume : The total estimated value of transactions on the Bitcoin blockchain.
#
# ## Problem Statement
#
# The aim of this analysis is to visualize the dataset based on the time period to analyze its price over time .Plotting the patterns of different variables helps us understand to predict he future price of bitcoin.
#
# ## Exercise
#     - Ingest the dataset into a format that is easy for analysis
#     - Explanatory data analysis and visualization of data
#     - Predicting the future price
#
# ###  Steps to follow:
#
# 1. Create a dataframe and load the data into the dataframe. This step has been performed for you. A dataframe called          'bit_df' has been created and the dataset available at a remote server location is loaded into the dataframe.
#
#    Recommended reading:
#
#    - Lesson on Dataframes in Junior Data Scientist/Data Analyst course on Refactored Platform
#    - https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html
#    - https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html
#
# 2. One objective of the analysis is to compare the exchange rate to date.In order to calculate the exchange rate use the formula
#     Exchange rate=Value in USD/Number of bitcoins
#
#    Recommended reading:
#     - Lesson on Dataframes in Junior Data Scientist/Data Analyst course on Refactored Platform
#     - https://pandas.pydata.org/pandas-docs/stable/indexing.html
# 3.

# %%
#initial_code, the code written here will be shown to user, write here initial setup to help user get started.
# %matplotlib inline 
from matplotlib.offsetbox import AnchoredText
import numpy as np 
import pandas as pd 
import datetime as dt
import itertools
import matplotlib.pyplot as plt 
import matplotlib.dates as mdates
import seaborn as sns

plt.style.use('ggplot')
# reading in data from the provided csv file
bit_df = pd.read_csv('https://raw.githubusercontent.com/colaberry/data/master/Bitcoin/bitcoin_dataset.csv',encoding='utf-8',index_col=0)
bit_df.head(5)
# Out:
#            btc_market_price  btc_total_bitcoins  btc_market_cap  \
# Date
# 2/17/2010               0.0           2043200.0             0.0
# 2/18/2010               0.0           2054650.0             0.0
# 2/19/2010               0.0           2063600.0             0.0
# 2/20/2010               0.0           2074700.0             0.0
# 2/21/2010               0.0           2085400.0             0.0
#
#            btc_trade_volume  btc_blocks_size  btc_avg_block_size  \
# Date
# 2/17/2010               0.0              0.0            0.000235
# 2/18/2010               0.0              0.0            0.000241
# 2/19/2010               0.0              0.0            0.000228
# 2/20/2010               0.0              0.0            0.000218
# 2/21/2010               0.0              0.0            0.000234
#
#            btc_n_orphaned_blocks  btc_n_transactions_per_block  \
# Date
# 2/17/2010                      0                           1.0
# ...

# %% [markdown]
# # Solution
#
# ## Find the exchange rate
#    - Exchange rate can be calculated as  Exchange rate=Value in USD/Number of bitcoins

# %%
#answer, write code which is a solution for above question.
bit_df['date']=
bit_df['exch_rate']=(bit_df.btc_market_price/bit_df.btc_total_bitcoins) 
bit_df
# Out:
#            btc_market_price  btc_total_bitcoins  btc_market_cap  \
# Date
# 2/17/2010           0.00000           2043200.0    0.000000e+00
# 2/18/2010           0.00000           2054650.0    0.000000e+00
# 2/19/2010           0.00000           2063600.0    0.000000e+00
# 2/20/2010           0.00000           2074700.0    0.000000e+00
# 2/21/2010           0.00000           2085400.0    0.000000e+00
# 2/22/2010           0.00000           2098150.0    0.000000e+00
# 2/23/2010           0.00000           2110700.0    0.000000e+00
# 2/24/2010           0.00000           2120200.0    0.000000e+00
# 2/25/2010           0.00000           2127600.0    0.000000e+00
# 2/26/2010           0.00000           2136100.0    0.000000e+00
# 2/27/2010           0.00000           2144750.0    0.000000e+00
# 2/28/2010           0.00000           2152850.0    0.000000e+00
# 3/1/2010            0.00000           2162150.0    0.000000e+00
# 3/2/2010            0.00000           2171950.0    0.000000e+00
# ...

# %%
#this is assertion block which verifies the solution.

try:
    def verify_answer():
        if bit_df['exch_rate']==(bit_df.btc_market_price/bit_df.btc_total_bitcoins):
            ref_assert_var=True
        else:
            ref_assert_var=False
        
    ref_assert_var = verify_answer()
except Exception as e:
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')
# Out:
# Your assertion block throws error: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# ## Data Visualization
#
# We have created a dataframe with the exchange rate in the previous exercise.Let us try to visualize it in a timeseries plot,plotting 'exch_rate' variable on y-axis and the 'date' on x-axis

# %% [markdown]
# ### Use tsplot funtion in seaborn library to generate a timeseries plot

# %%
#answer, write code which is a solution for above question.
plt.subplots(figsize=(16, 4))
sns.tsplot(bit_df['exch_rate'], time=bit_df.index, condition='Bitcoin exchange rate', color='red')

plt.ylabel('USD exchange rate')
plt.xlabel('Date')
plt.title('Bitcoin exchange rate with USD')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'exch_rate'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...
