# %% [markdown]
# # PYTHON INTRODUCTION
#
#
# ## Variables in python
# Variable is just a name that stores data.
# To create a variable, you have to use '=' operator.
# `my_var = 100`
#
#
# ## Exercise
#
# - create a variable with name 'stoic' and assign 999 to it.

# %%
"""task is to

Ingest the data into a format that is easy for analysis.
Perform Exploratory Data Analysis on the dataset.
 predict the future price of the dataset"""
# Out:
# 'task is to\n\nIngest the data into a format that is easy for analysis.\nPerform Exploratory Data Analysis on the dataset.\n predict the future price of the dataset'

# %% [markdown]
# #### this is the hint block, use code cell or markdown cell, but remember it wont get executed, so better go with markdown.
#
# Use '=' operator to create and assign value to variable.

# %%
from matplotlib.offsetbox import AnchoredText

import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import itertools
import matplotlib.dates as mdates
# %matplotlib inline 



#import xgboost as xgb
#import data_ingest

from sklearn.preprocessing import LabelEncoder

#Reading Datasets
one=pd.read_csv('https://raw.githubusercontent.com/colaberry/data/master/Bitcoin/bitcoin_dataset.csv', encoding='utf-8') 
two=pd.read_csv('https://raw.githubusercontent.com/colaberry/data/master/Bitcoin/test_set.csv',encoding='utf-8') 
sample=two.head(16)
sample
sample_one=one.head(2908)
sample_one
# Out:
#            Date  btc_market_price  btc_total_bitcoins  btc_market_cap  \
# 0     2/17/2010           0.00000           2043200.0    0.000000e+00
# 1     2/18/2010           0.00000           2054650.0    0.000000e+00
# 2     2/19/2010           0.00000           2063600.0    0.000000e+00
# 3     2/20/2010           0.00000           2074700.0    0.000000e+00
# 4     2/21/2010           0.00000           2085400.0    0.000000e+00
# 5     2/22/2010           0.00000           2098150.0    0.000000e+00
# 6     2/23/2010           0.00000           2110700.0    0.000000e+00
# 7     2/24/2010           0.00000           2120200.0    0.000000e+00
# 8     2/25/2010           0.00000           2127600.0    0.000000e+00
# 9     2/26/2010           0.00000           2136100.0    0.000000e+00
# 10    2/27/2010           0.00000           2144750.0    0.000000e+00
# 11    2/28/2010           0.00000           2152850.0    0.000000e+00
# ...

# %%
"""
1)Ingestion:
Inserting is  the process of obtaining and importing data for immediate use or storage in a database and we are importing both the datasets and printing 
them, for easy analysis.
2)Exploratory Data Analysis:
We plotted the graphs using EDA Techniques i.e linear regression and logistic regression..
We plotted the graph taking Date on X-axis and market price on Y and hence caluculated the percentile on its variation.
We also plotted the graphs between the btc_trade_volume and the total bit coins and the miners revenue.
3)Predicting the future prices:
Use the first time period to generate all possible time series of length n
       and their corresponding label.
    Args:
        btc_market_price: A numpy array of floats representing prices over the first time
            period.
        n: An integer (180, 360, or 720) representing the length of time series.
            
        
        Use the second time period to generate the independent and dependent variables
       in the linear regression model Δp = w0 + w1 * Δp1 + w2 * Δp2 + w3 * Δp3 + w4 * r.
    Args:
        btc_market_price: A numpy array of floats representing prices over the second time
            period.
        btc_trade_volume: A numpy array of floats representing total volumes people are
            willing to buy over the second time period.
        btc_miners_revenue: A numpy array of floats representing total volumes people are
            willing to sell over the second time period.
        s1: A 2-dimensional numpy array generated by choose_effective_centers()
        s2: A 2-dimensional numpy array generated by choose_effective_centers().
        s3: A 2-dimensional numpy array generated by choose_effective_centers().
    Returns:
        A tuple (X, Y) representing the independent and dependent variables in
        the linear regression model. X is a 2-dimensional numpy array and each
        row represents [Δp1, Δp2, Δp3, r]. Y is a numpy array of floats and
        each array element represents Δp."""

"""Predict the average price change Δp_i, 1 <= i <= 3.
59
60
    Args:
61
        x: A numpy array of floats representing previous 180, 360, or 720 prices.
62
        s: A 2-dimensional numpy array generated by choose_effective_centers().
63
64
    Returns:
65
66
    """
# Out:
# '\n1)Ingestion:\nInserting is  the process of obtaining and importing data for immediate use or storage in a database and we are importing both the datasets and printing \nthem, for easy analysis.\n2)Exploratory Data Analysis:\nWe plotted the graphs using EDA Techniques i.e linear regression and logistic regression..\nWe plotted the graph taking Date on X-axis and market price on Y and hence caluculated the percentile on its variation.\nWe also plotted the graphs between the btc_trade_volume and the total bit coins and the miners revenue.\n3)Predicting the future prices:\nUse the first time period to generate all possible time series of length n\n       and their corresponding label.\n    Args:\n        btc_market_price: A numpy array of floats representing prices over the first time\n            period.\n        n: An integer (180, 360, or 720) representing the length of time series.\n    Returns:\n        A 2-dimensional numpy array of size (len(prices)-n) x (n+1). Each row\n      
# ...

# %% [markdown]
# <br/><br/><br/><br/>
# ## Importing modules
#
# Use 'import' keyword.
#
# ## Exercise
# -  import os

# %%
import os


#Grouping 
total_ext_df = pd.DataFrame(one[['btc_total_bitcoins','Date']].groupby('Date').sum())
total_ext_df.head()

#Exploring the data with the market price and the Date of observation
plt.subplots(figsize=(16, 4))
sns.tsplot(total_ext_df['btc_total_bitcoins'], condition='Change Of Market Price', color='blue')
plt.ylabel('Variation Of Market Price with Date')
plt.xlabel('Date')
plt.title('Total Change')
plt.show()
sns.despine



one.describe()

plt.rcParams['font.size']=11 
plt.rcParams['figure.figsize']=[8.0, 3.5] 
fig, axes=plt.subplots(nrows=1, ncols=2) 
one.plot(kind='scatter', x='btc_trade_volume', y='btc_total_bitcoins', ax=axes[0], color='Blue'); 
one.plot(kind='scatter', x='btc_trade_volume', y='btc_miners_revenue', ax=axes[1], color='Red'); 
plt.tight_layout()



two.describe()

plt.rcParams['font.size']=11 
plt.rcParams['figure.figsize']=[8.0, 3.5] 
fig, axes=plt.subplots(nrows=1, ncols=2) 
two.plot(kind='scatter', x='btc_market_cap', y='btc_market_cap', ax=axes[0], color='Blue'); 
two.plot(kind='scatter', x='btc_market_cap', y='btc_trade_volume', ax=axes[1], color='Red'); 
plt.tight_layout()



#perdiction of future prices dataset 

def generate_timeseries(btc_market_price, n):
    
    m = len(btc_market_price) - n
    ts = np.empty((m, n + 1))
    for i in range(m):
        ts[i, :n] = btc_market_price[i:i + n]
        ts[i, n] = btc_market_price[i + n] - btc_market_price[i + n - 1]
    return ts
 

def linear_regression_vars(btc_market_price, btc_trade_volume, btc_miners_revenue, s1, s2, s3):
    
    X = np.empty((len() - 721, 4))
    Y = np.empty(len(btc_market_price) - 721)
    for i in range(720, len(btc_market_price) - 1):
        dp = btc_market_price[i + 1] - btc_market_price[i]
        dp1 = predict_dpi(btc_market_price[i - 180:i], s1)
        dp2 = predict_dpi(btc_market_price[i - 360:i], s2)
        dp3 = predict_dpi(btc_market_price[i - 720:i], s3)
        r = (btc_trade_volume[i] - btc_miners_revenue[i]) / (btc_trade_volume[i] + btc_miners_revenue[i])
        X[i - 720, :] = [dp1, dp2, dp3, r]
        Y[i - 720] = dp
    
        return X,Y

# %%
"""Returns:
        A 2-dimensional numpy array of size (len(prices)-n) x (n+1). Each row
        represents a time series of length n and its corresponding label
        (n+1-th column).
        A big float representing average price change Δp_i.
"""
# Out:
# 'Returns:\n        A 2-dimensional numpy array of size (len(prices)-n) x (n+1). Each row\n        represents a time series of length n and its corresponding label\n        (n+1-th column).\n        A big float representing average price change Δp_i.\n'
